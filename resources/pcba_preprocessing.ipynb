# %% [markdown]
# # PCBA pre-processing
#
# The pre-processed data is available [here](https://github.com/BorealisAI/MMoEEx-MTL/mtl_datasets/pcba_dataset) (INCOMPLETE LINK).
#
# In case you want to do the pre-processing, see the instructions below.
#
# a. If working with conda env, download the raw data [here](https://github.com/deepchem/deepchem/raw/master/datasets/pcba.csv.gz) and run the following code inside your conda env:
# ```
# pip install tensorflow-gpu==1.14
# conda install -y -c conda-forge rdkit deepchem==2.3.0
# python MMoEEx-MTL/src/data_pcba.py
# ```
#
# b. This notebook also performs the pre-processing in Google Colab. Just run the following cells sequentially.

# %%
# !pip install wget
# !pip install -q condacolab
import condacolab
condacolab.install()
# !pip install tensorflow-gpu==1.14
# !conda install rdkit deepchem==2.3.0
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp37-none-any.whl size=9681 sha256=f2b22dd745a8238683af4912c8aa9627becebcb39770f3c58755aa19c4d892f1
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:50
# 🔁 Restarting kernel...
# ...
#      |████████████████████████████████| 377.1 MB 8.6 kB/s
# ...
#      |████████████████████████████████| 1.0 MB 36.9 MB/s
# ...
#      |████████████████████████████████| 488 kB 41.4 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 28.1 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 25.6 MB/s
# ...
#      |████████████████████████████████| 15.3 MB 232 kB/s
# ...
#      |████████████████████████████████| 42 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.0 MB/s
# ...

# %%
# !mkdir mtl_datasets
# !mkdir mtl_datasets/census_dataset
# !mkdir mtl_datasets/pcba_dataset
# !wget -c "https://github.com/deepchem/deepchem/raw/master/datasets/pcba.csv.gz" -P 'mtl_datasets/pcba_dataset'
# Out:
# --2021-05-20 06:15:39--  https://github.com/deepchem/deepchem/raw/master/datasets/pcba.csv.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/deepchem/deepchem/master/datasets/pcba.csv.gz [following]
# --2021-05-20 06:15:39--  https://raw.githubusercontent.com/deepchem/deepchem/master/datasets/pcba.csv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15497027 (15M) [application/octet-stream]
# Saving to: ‘mtl_datasets/pcba_dataset/pcba.csv.gz’
#
# pcba.csv.gz         100%[===================>]  14.78M  59.8MB/s    in 0.2s
#
# ...

# %%
#data_preprocessing 
import wget

#try load, except download and load 
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/census-income-mld/census-income.data.gz'
wget.download(url, 'mtl_datasets/census_dataset/census-income.data.gz')

url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/census-income-mld/census-income.test.gz'
wget.download(url, 'mtl_datasets/census_dataset/census-income.test.gz')
# Out:
# 'mtl_datasets/census_dataset/census-income.test.gz'

# %%
from data_preprocessing import *
run_dataprep('/content')
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...
